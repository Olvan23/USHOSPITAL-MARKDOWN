# %%
import pandas as pd

# %%
d1 = pd.read_csv('/Users/OLVAN/Documents/data/Hospital_General_Information.csv')
d2= pd.read_csv('/Users/OLVAN/Documents/data/hospital_locations.csv')

# %%
d1.head()
d2.head()
# Out:
#    index            X            Y  OBJECTID        ID  \
# 0      0 -13226507.27  4049625.553         2  53391362
# 1      1 -13156201.05  4031977.723         3  11190023
# 2      2 -13171904.89  4041752.386         4  17090028
# 3      3 -13132075.10  4037269.759         5  23691706
# 4      4 -13152220.06  4009979.573         6  25190712
#
#                                                 NAME  \
# 0  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 1                  EAST LOS ANGELES DOCTORS HOSPITAL
# 2          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 3                      KINDRED HOSPITAL BALDWIN PARK
# 4                   LAKEWOOD REGIONAL MEDICAL CENTER
#
#                      ADDRESS             CITY STATE    ZIP  ...  \
# 0             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  ...
# 1    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  ...
# 2     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  ...
# ...

# %%
d1.head()
# Out:
#    index        ID                                              NAME  \
# 0   39.0  140018.0                  MT SINAI HOSPITAL MEDICAL CENTER
# 1   69.0  230132.0                             HURLEY MEDICAL CENTER
# 2   73.0  230273.0   DETROIT RECEIVING HOSPITAL & UNIV HEALTH CENTER
# 3  119.0  290045.0        ST ROSE DOMINICAN HOSPITALS - SIENA CAMPUS
# 4  127.0  310110.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
#
#                      Address       City State      ZIP   COUNTY     TELEPHONE  \
# 0  15TH STREET AT CALIFORNIA    CHICAGO    IL  60608.0     COOK  7.732577e+09
# 1           ONE HURLEY PLAZA      FLINT    MI  48503.0  GENESEE  8.102579e+09
# 2    4201 ST ANTOINE ST - 3M    DETROIT    MI  48201.0    WAYNE  3.137453e+09
# 3       3001 ST ROSE PARKWAY  HENDERSON    NV  89052.0    CLARK  7.026165e+09
# 4  ONE HAMILTON HEALTH PLACE   HAMILTON    NJ   8690.0   MERCER  6.095868e+09
#
#                    TYPE  ... Readmission national comparison footnote  \
# ...

# %%
import matplotlib as plt

# %%
d2.columns
# Out:
# Index(['index', 'X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')

# %%
d1.columns
# Out:
# Index(['index', 'ID', 'NAME', 'Address', 'City', 'State', 'ZIP', 'COUNTY',
#        'TELEPHONE', 'TYPE', 'OWNER', 'EMERGENCY',
#        'Meets criteria for meaningful use of EHRs', 'RATINGS',
#        'Hospital overall rating footnote', 'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
#        'Efficient use of medical imaging national comparison',
# ...

# %%
d2= d2.rename(columns=str.lower)

# %%
d1= d1.rename(columns=str.lower)

# %%
d1.head()
# Out:
#    index        id                                              name  \
# 0   39.0  140018.0                  MT SINAI HOSPITAL MEDICAL CENTER
# 1   69.0  230132.0                             HURLEY MEDICAL CENTER
# 2   73.0  230273.0   DETROIT RECEIVING HOSPITAL & UNIV HEALTH CENTER
# 3  119.0  290045.0        ST ROSE DOMINICAN HOSPITALS - SIENA CAMPUS
# 4  127.0  310110.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
#
#                      address       city state      zip   county     telephone  \
# 0  15TH STREET AT CALIFORNIA    CHICAGO    IL  60608.0     COOK  7.732577e+09
# 1           ONE HURLEY PLAZA      FLINT    MI  48503.0  GENESEE  8.102579e+09
# 2    4201 ST ANTOINE ST - 3M    DETROIT    MI  48201.0    WAYNE  3.137453e+09
# 3       3001 ST ROSE PARKWAY  HENDERSON    NV  89052.0    CLARK  7.026165e+09
# 4  ONE HAMILTON HEALTH PLACE   HAMILTON    NJ   8690.0   MERCER  6.095868e+09
#
#                    type  ... readmission national comparison footnote  \
# ...

# %%
missing_data = d1.isnull()
missing_data.head()
# Out:
#    index     id   name  address   city  state    zip  county  telephone  \
# 0  False  False  False    False  False  False  False   False      False
# 1  False  False  False    False  False  False  False   False      False
# 2  False  False  False    False  False  False  False   False      False
# 3  False  False  False    False  False  False  False   False      False
# 4  False  False  False    False  False  False  False   False      False
#
#     type  ...  readmission national comparison footnote  \
# 0  False  ...                                      True
# 1  False  ...                                      True
# 2  False  ...                                      True
# 3  False  ...                                      True
# 4  False  ...                                      True
#
#    patient experience national comparison  \
# 0                                   False
# 1                                   False
# 2                                   False
# ...

# %%
missing_data2 = d2.isnull()
missing_data2.head()
# Out:
#    index      x      y  objectid     id   name  address   city  state    zip  \
# 0  False  False  False     False  False  False    False  False  False  False
# 1  False  False  False     False  False  False    False  False  False  False
# 2  False  False  False     False  False  False    False  False  False  False
# 3  False  False  False     False  False  False    False  False  False  False
# 4  False  False  False     False  False  False    False  False  False  False
#
#    ...  val_date  website  state_id  alt_name  st_fips  owner  ttl_staff  \
# 0  ...     False    False     False     False    False  False      False
# 1  ...     False    False     False     False    False  False      False
# 2  ...     False    False     False     False    False  False      False
# 3  ...     False    False     False     False    False  False      False
# 4  ...     False    False     False     False    False  False      False
#
#     beds  trauma  helipad
# 0  False   False    False
# ...

# %%
# How many cells are empty and the Datatypes in each columns
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# index
# False    4818
# True        1
# Name: index, dtype: int64
#
# id
# False    4818
# True        1
# Name: id, dtype: int64
#
# name
# False    4818
# True        1
# Name: name, dtype: int64
#
# address
# False    4818
# True        1
# Name: address, dtype: int64
#
# city
# False    4818
# True        1
# Name: city, dtype: int64
#
# state
# False    4818
# True        1
# Name: state, dtype: int64
#
# zip
# False    4818
# True        1
# Name: zip, dtype: int64
#
# county
# False    4803
# True       16
# Name: county, dtype: int64
#
# telephone
# False    4818
# True        1
# Name: telephone, dtype: int64
#
# type
# False    4818
# True        1
# Name: type, dtype: int64
#
# owner
# False    4818
# True        1
# Name: owner, dtype: int64
#
# emergency
# False    4818
# True        1
# Name: emergency, dtype: int64
#
# meets criteria for meaningful use of ehrs
# True    4819
# Name: meets criteria for meaningful use of ehrs, dtype: int64
#
# ratings
# False    3648
# ...

# %%
d1.dtypes
# Out:
# index                                                            float64
# id                                                               float64
# name                                                              object
# address                                                           object
# city                                                              object
# state                                                             object
# zip                                                              float64
# county                                                            object
# telephone                                                        float64
# type                                                              object
# owner                                                             object
# emergency                                                         object
# meets criteria for meaningful use of ehrs                        float64
# ...

# %%
d2.dtypes
# Out:
# index           int64
# x             float64
# y             float64
# objectid        int64
# id              int64
# name           object
# address        object
# city           object
# state          object
# zip             int64
# zip4           object
# telephone      object
# type           object
# status         object
# population      int64
# county         object
# countyfips     object
# country        object
# latitude      float64
# longitude     float64
# naics_code      int64
# naics_desc     object
# source         object
# sourcedate     object
# val_method     object
# val_date       object
# website        object
# state_id       object
# alt_name       object
# st_fips         int64
# owner          object
# ttl_staff       int64
# beds            int64
# trauma         object
# helipad        object
# dtype: object

# %%
#dropping empty columns
import numpy as np
d1.dropna(how ='all', axis=1, inplace =True)
df1=pd.DataFrame(d1)

# %%
#show dataframe
df1.head()
# Out:
#    index        id                                              name  \
# 0   39.0  140018.0                  MT SINAI HOSPITAL MEDICAL CENTER
# 1   69.0  230132.0                             HURLEY MEDICAL CENTER
# 2   73.0  230273.0   DETROIT RECEIVING HOSPITAL & UNIV HEALTH CENTER
# 3  119.0  290045.0        ST ROSE DOMINICAN HOSPITALS - SIENA CAMPUS
# 4  127.0  310110.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
#
#                      address       city state      zip   county     telephone  \
# 0  15TH STREET AT CALIFORNIA    CHICAGO    IL  60608.0     COOK  7.732577e+09
# 1           ONE HURLEY PLAZA      FLINT    MI  48503.0  GENESEE  8.102579e+09
# 2    4201 ST ANTOINE ST - 3M    DETROIT    MI  48201.0    WAYNE  3.137453e+09
# 3       3001 ST ROSE PARKWAY  HENDERSON    NV  89052.0    CLARK  7.026165e+09
# 4  ONE HAMILTON HEALTH PLACE   HAMILTON    NJ   8690.0   MERCER  6.095868e+09
#
#                    type  ... readmission national comparison footnote  \
# ...

# %%
df1.dropna(axis=1)
# Out:
#        index        id                                              name  \
# 0       39.0  140018.0                  MT SINAI HOSPITAL MEDICAL CENTER
# 1       69.0  230132.0                             HURLEY MEDICAL CENTER
# 2       73.0  230273.0   DETROIT RECEIVING HOSPITAL & UNIV HEALTH CENTER
# 3      119.0  290045.0        ST ROSE DOMINICAN HOSPITALS - SIENA CAMPUS
# 4      127.0  310110.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
# ...      ...       ...                                               ...
# 4813  4807.0  450808.0                 NORTHWEST HILLS SURGICAL HOSPITAL
# 4814  4810.0  501325.0                          FORKS COMMUNITY HOSPITAL
# 4815  4812.0  521356.0                     BELLIN HEALTH OCONTO HOSPITAL
# 4816  4815.0  501310.0                        NEWPORT COMMUNITY HOSPITAL
# 4817  4816.0  670107.0                   BAYLOR EMERGENCY MEDICAL CENTER
#
#                              address       city state      zip     telephone  \
# ...

# %%
#dropping empty columns in dataframe2
import numpy as np
d2.dropna(how ='all', axis=1, inplace =True)
df2=pd.DataFrame(d2)

# %%
df2.head()
# Out:
#    index            x            y  objectid        id  \
# 0      0 -13226507.27  4049625.553         2  53391362
# 1      1 -13156201.05  4031977.723         3  11190023
# 2      2 -13171904.89  4041752.386         4  17090028
# 3      3 -13132075.10  4037269.759         5  23691706
# 4      4 -13152220.06  4009979.573         6  25190712
#
#                                                 name  \
# 0  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 1                  EAST LOS ANGELES DOCTORS HOSPITAL
# 2          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 3                      KINDRED HOSPITAL BALDWIN PARK
# 4                   LAKEWOOD REGIONAL MEDICAL CENTER
#
#                      address             city state    zip  ...  \
# 0             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  ...
# 1    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  ...
# 2     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  ...
# ...

# %%
df2.dropna(axis=1)
# Out:
#       index             x            y  objectid         id  \
# 0         0 -1.322651e+07  4049625.553         2   53391362
# 1         1 -1.315620e+07  4031977.723         3   11190023
# 2         2 -1.317190e+07  4041752.386         4   17090028
# 3         3 -1.313208e+07  4037269.759         5   23691706
# 4         4 -1.315222e+07  4009979.573         6   25190712
# ...     ...           ...          ...       ...        ...
# 7618   7618 -8.394315e+06  4678659.754      7825  196784304
# 7619   7619 -1.087172e+07  3861478.991      7826  196784305
# 7620   7620 -1.298899e+07  4200987.461      7827  196784306
# 7621   7621 -1.086452e+07  3924259.275      7828  196784307
# 7622   7622 -1.045536e+07  5143663.063      7829  196784308
#
#                                                    name  \
# 0     LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 1                     EAST LOS ANGELES DOCTORS HOSPITAL
# 2             SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# ...

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (4818, 29)
# (7623, 35)

# %%
df_combine = df1.merge(df2, left_on="id",right_on ="id", how='left')

# %%
df_combine
# Out:
#       index_x        id                                            name_x  \
# 0        39.0  140018.0                  MT SINAI HOSPITAL MEDICAL CENTER
# 1        69.0  230132.0                             HURLEY MEDICAL CENTER
# 2        73.0  230273.0   DETROIT RECEIVING HOSPITAL & UNIV HEALTH CENTER
# 3       119.0  290045.0        ST ROSE DOMINICAN HOSPITALS - SIENA CAMPUS
# 4       127.0  310110.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
# ...       ...       ...                                               ...
# 4813   4807.0  450808.0                 NORTHWEST HILLS SURGICAL HOSPITAL
# 4814   4810.0  501325.0                          FORKS COMMUNITY HOSPITAL
# 4815   4812.0  521356.0                     BELLIN HEALTH OCONTO HOSPITAL
# 4816   4815.0  501310.0                        NEWPORT COMMUNITY HOSPITAL
# 4817   4816.0  670107.0                   BAYLOR EMERGENCY MEDICAL CENTER
#
#                            address_x     city_x state_x    zip_x  \
# ...

# %%
df_combine.head(5000)
# Out:
#       index_x        id                                            name_x  \
# 0        39.0  140018.0                  MT SINAI HOSPITAL MEDICAL CENTER
# 1        69.0  230132.0                             HURLEY MEDICAL CENTER
# 2        73.0  230273.0   DETROIT RECEIVING HOSPITAL & UNIV HEALTH CENTER
# 3       119.0  290045.0        ST ROSE DOMINICAN HOSPITALS - SIENA CAMPUS
# 4       127.0  310110.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
# ...       ...       ...                                               ...
# 4813   4807.0  450808.0                 NORTHWEST HILLS SURGICAL HOSPITAL
# 4814   4810.0  501325.0                          FORKS COMMUNITY HOSPITAL
# 4815   4812.0  521356.0                     BELLIN HEALTH OCONTO HOSPITAL
# 4816   4815.0  501310.0                        NEWPORT COMMUNITY HOSPITAL
# 4817   4816.0  670107.0                   BAYLOR EMERGENCY MEDICAL CENTER
#
#                            address_x     city_x state_x    zip_x  \
# ...

# %%
df3 = pd.DataFrame(df_combine.dropna(axis=1))
df3.head()
# Out:
#    index_x        id                                            name_x  \
# 0     39.0  140018.0                  MT SINAI HOSPITAL MEDICAL CENTER
# 1     69.0  230132.0                             HURLEY MEDICAL CENTER
# 2     73.0  230273.0   DETROIT RECEIVING HOSPITAL & UNIV HEALTH CENTER
# 3    119.0  290045.0        ST ROSE DOMINICAN HOSPITALS - SIENA CAMPUS
# 4    127.0  310110.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
#
#                    address_x     city_x state_x    zip_x   telephone_x  \
# 0  15TH STREET AT CALIFORNIA    CHICAGO      IL  60608.0  7.732577e+09
# 1           ONE HURLEY PLAZA      FLINT      MI  48503.0  8.102579e+09
# 2    4201 ST ANTOINE ST - 3M    DETROIT      MI  48201.0  3.137453e+09
# 3       3001 ST ROSE PARKWAY  HENDERSON      NV  89052.0  7.026165e+09
# 4  ONE HAMILTON HEALTH PLACE   HAMILTON      NJ   8690.0  6.095868e+09
#
#                  type_x                         owner_x emergency  \
# ...

# %%
df3.to_csv('C:/Users/OLVAN/Desktop/combined.csv')

# %%
groupby_type=df3['owner_x'].groupby(df3['type_x'])

# %%
groupby_type.head()
# Out:
# 0                    Voluntary non-profit - Private
# 1                      Voluntary non-profit - Other
# 2                                       Proprietary
# 3                    Voluntary non-profit - Private
# 4                    Voluntary non-profit - Private
# 121                                     Proprietary
# 166                  Voluntary non-profit - Private
# 224                              Government - Local
# 277                  Voluntary non-profit - Private
# 308     Government - Hospital District or Authority
# 3656                 Voluntary non-profit - Private
# 3662                 Voluntary non-profit - Private
# 3674                   Voluntary non-profit - Other
# 3710                 Voluntary non-profit - Private
# 3716                 Voluntary non-profit - Private
# Name: owner_x, dtype: object

# %%
# count all values in type column
print(df3['type_x'].value_counts())
# Out:
# Acute Care Hospitals         3382
# Critical Access Hospitals    1337
# Childrens                      99
# Name: type_x, dtype: int64

# %%
# count all values in owner column
print(df3['owner_x'].value_counts())
# Out:
# Voluntary non-profit - Private                 2027
# Proprietary                                     799
# Government - Hospital District or Authority     567
# Voluntary non-profit - Other                    477
# Government - Local                              412
# Voluntary non-profit - Church                   349
# Government - State                               67
# Physician                                        66
# Government - Federal                             46
# Tribal                                            8
# Name: owner_x, dtype: int64

# %%
# count all values in city column
print(df3['city_x'].value_counts())
# Out:
# CHICAGO             29
# HOUSTON             26
# LOS ANGELES         20
# PHILADELPHIA        19
# DALLAS              19
#                     ..
# EAST CHINA           1
# GOLDSBORO            1
# LAKE SAINT LOUIS     1
# DEXTER               1
# OCONTO               1
# Name: city_x, Length: 2949, dtype: int64

# %%
# describe all values in ratings column
print(df1['ratings'].describe())
# Out:
# count    3648.000000
# mean        3.073465
# std         0.834595
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: ratings, dtype: float64

# %%
# count all values in ratings column from Hospital_General_Information
print(df1['ratings'].value_counts())
# Out:
# 3.0    1772
# 4.0     964
# 2.0     684
# 1.0     117
# 5.0     111
# Name: ratings, dtype: int64

# %%
groupby_ratings=df1.groupby('ratings', axis=0)

# %%
groupby_ratings.head()
# Out:
#       index        id                                               name  \
# 0      39.0  140018.0                   MT SINAI HOSPITAL MEDICAL CENTER
# 1      69.0  230132.0                              HURLEY MEDICAL CENTER
# 2      73.0  230273.0    DETROIT RECEIVING HOSPITAL & UNIV HEALTH CENTER
# 3     119.0  290045.0         ST ROSE DOMINICAN HOSPITALS - SIENA CAMPUS
# 4     127.0  310110.0   ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
# 117    11.0   30084.0          CHINLE COMPREHENSIVE HEALTH CARE FACILITY
# 118    12.0   40007.0                           CHI-ST VINCENT INFIRMARY
# 119    18.0   50055.0  CALIFORNIA PACIFIC MEDICAL CTR - ST. LUKE'S CA...
# 120    30.0  100137.0           HEART OF FLORIDA REGIONAL MEDICAL CENTER
# 121    49.0  171373.0                     ALLEN COUNTY REGIONAL HOSPITAL
# 801     0.0   10005.0                      MARSHALL MEDICAL CENTER SOUTH
# 802     2.0   10131.0                           CRESTWOOD MEDICAL CENTER
# ...

# %%
# Binning of the rating based on a condition
df1.loc[df1.ratings < 3, 'ratings'] = 0
df1.loc[df1.ratings >= 3, 'ratings'] = 1
# Grouping and couting
df1.groupby('ratings').count()
# Out:
#          index    id  name  address  city  state   zip  county  telephone  \
# ratings
# 0.0        801   801   801      801   801    801   801     798        801
# 1.0       2847  2847  2847     2847  2847   2847  2847    2846       2847
#
#          type  ...  readmission national comparison footnote  \
# ratings        ...
# 0.0       801  ...                                         7
# 1.0      2847  ...                                       117
#
#          patient experience national comparison  \
# ratings
# 0.0                                         801
# 1.0                                        2847
#
#          patient experience national comparison footnote  \
# ratings
# 0.0                                                   30
# 1.0                                                  243
#
#          effectiveness of care national comparison  \
# ratings
# 0.0                                            801
# 1.0                                           2847
#
# ...

# %%
df3['type_x'].value_counts().plot()
plt.pyplot.xlabel("HOSPITAL TYPES")
# Out:
# Text(0.5, 0, 'HOSPITAL TYPES')

# %%
df3['owner_x'].value_counts().plot.bar()
plt.pyplot.xlabel("OWNERS")
# Out:
# Text(0.5, 0, 'OWNERS')
